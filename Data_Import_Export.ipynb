# %% [markdown]
# # Import Data in Python

# %% [markdown]
# # Import CSV files
#
#
# It is important to note that a single backslash does not work when specifying the file path. You need to either change it to forward slash or add one more backslash like below

# %%
import pandas as pd
mydata= pd.read_csv("C:\\Users\\croma\\Dexlab python\\python\\Custom_Diabetes_Dataset (1).csv")
mydata
# Out:
#      pregnancies  plasma glucose  blood pressure  triceps skin thickness  \
# 0              6             148              72                      35
# 1              1              85              66                      29
# 2              8             183              64                       0
# 3              1              89              66                      23
# 4              0             137              40                      35
# 5              5             116              74                       0
# 6              3              78              50                      32
# 7             10             115               0                       0
# 8              2             197              70                      45
# 9              8             125              96                       0
# 10             4             110              92                       0
# 11            10             168              74                       0
# 12            10             139              80                       0
# 13             1             189              60                      23
# 14             5             166              72                      19
# 15             7             100               0                       0
# 16             0             118              84                      47
# 17             7             107              74                       0
# 18             1             103              30                      38
# 19             1             115              70                      30
# 20             3             126              88                      41
# 21             8              99              84                       0
# 22             7             196              90                       0
# 23             9             119              80                      35
# 24            11             143              94                      33
# 25            10             125              70                      26
# 26             7             147              76                       0
# 27             1              97              66                      15
# 28            13             145              82                      19
# 29             5             117              92                       0
# ..           ...             ...             ...                     ...
# 738            2              99              60                      17
# 739            1             102              74                       0
# 740           11             120              80                      37
# 741            3             102              44                      20
# 742            1             109              58                      18
# 743            9             140              94                       0
# 744           13             153              88                      37
# 745           12             100              84                      33
# 746            1             147              94                      41
# 747            1              81              74                      41
# 748            3             187              70                      22
# 749            6             162              62                       0
# 750            4             136              70                       0
# 751            1             121              78                      39
# 752            3             108              62                      24
# 753            0             181              88                      44
# 754            8             154              78                      32
# 755            1             128              88                      39
# 756            7             137              90                      41
# 757            0             123              72                       0
# 758            1             106              76                       0
# 759            6             190              92                       0
# 760            2              88              58                      26
# 761            9             170              74                      31
# 762            9              89              62                       0
# 763           10             101              76                      48
# 764            2             122              70                      27
# 765            5             121              72                      23
# 766            1             126              60                       0
# 767            1              93              70                      31
#
#      insulin   bmi  diabetes pedigree  age  diabetes
# 0          0  33.6              0.627   50      True
# 1          0  26.6              0.351   31     False
# 2          0  23.3              0.672   32      True
# 3         94  28.1              0.167   21     False
# 4        168  43.1              2.288   33      True
# 5          0  25.6              0.201   30     False
# 6         88  31.0              0.248   26      True
# 7          0  35.3              0.134   29     False
# 8        543  30.5              0.158   53      True
# 9          0   0.0              0.232   54      True
# 10         0  37.6              0.191   30     False
# 11         0  38.0              0.537   34      True
# 12         0  27.1              1.441   57     False
# 13       846  30.1              0.398   59      True
# 14       175  25.8              0.587   51      True
# 15         0  30.0              0.484   32      True
# 16       230  45.8              0.551   31      True
# 17         0  29.6              0.254   31      True
# 18        83  43.3              0.183   33     False
# 19        96  34.6              0.529   32      True
# 20       235  39.3              0.704   27     False
# 21         0  35.4              0.388   50     False
# 22         0  39.8              0.451   41      True
# 23         0  29.0              0.263   29      True
# 24       146  36.6              0.254   51      True
# 25       115  31.1              0.205   41      True
# 26         0  39.4              0.257   43      True
# 27       140  23.2              0.487   22     False
# 28       110  22.2              0.245   57     False
# 29         0  34.1              0.337   38     False
# ..       ...   ...                ...  ...       ...
# 738      160  36.6              0.453   21     False
# 739        0  39.5              0.293   42      True
# 740      150  42.3              0.785   48      True
# 741       94  30.8              0.400   26     False
# 742      116  28.5              0.219   22     False
# 743        0  32.7              0.734   45      True
# 744      140  40.6              1.174   39     False
# 745      105  30.0              0.488   46     False
# 746        0  49.3              0.358   27      True
# 747       57  46.3              1.096   32     False
# 748      200  36.4              0.408   36      True
# 749        0  24.3              0.178   50      True
# 750        0  31.2              1.182   22      True
# 751       74  39.0              0.261   28     False
# 752        0  26.0              0.223   25     False
# 753      510  43.3              0.222   26      True
# 754        0  32.4              0.443   45      True
# 755      110  36.5              1.057   37      True
# 756        0  32.0              0.391   39     False
# 757        0  36.3              0.258   52      True
# 758        0  37.5              0.197   26     False
# 759        0  35.5              0.278   66      True
# 760       16  28.4              0.766   22     False
# 761        0  44.0              0.403   43      True
# 762        0  22.5              0.142   33     False
# 763      180  32.9              0.171   63     False
# 764        0  36.8              0.340   27     False
# 765      112  26.2              0.245   30     False
# 766        0  30.1              0.349   47      True
# 767        0  30.4              0.315   23     False
#
# [768 rows x 9 columns]

# %% [markdown]
# # Add Column Names
#
# We can include column names by using names= option.

# %%
#The variable names can also be added separately by using the following command.
mydata['three']=pd.Series([10,20,30],index=[0,2,3])
mydata
# Out:
#      pregnancies  plasma glucose  blood pressure  triceps skin thickness  \
# 0              6             148              72                      35
# 1              1              85              66                      29
# 2              8             183              64                       0
# 3              1              89              66                      23
# 4              0             137              40                      35
# 5              5             116              74                       0
# 6              3              78              50                      32
# 7             10             115               0                       0
# 8              2             197              70                      45
# 9              8             125              96                       0
# 10             4             110              92                       0
# 11            10             168              74                       0
# 12            10             139              80                       0
# 13             1             189              60                      23
# 14             5             166              72                      19
# 15             7             100               0                       0
# 16             0             118              84                      47
# 17             7             107              74                       0
# 18             1             103              30                      38
# 19             1             115              70                      30
# 20             3             126              88                      41
# 21             8              99              84                       0
# 22             7             196              90                       0
# 23             9             119              80                      35
# 24            11             143              94                      33
# 25            10             125              70                      26
# 26             7             147              76                       0
# 27             1              97              66                      15
# 28            13             145              82                      19
# 29             5             117              92                       0
# ..           ...             ...             ...                     ...
# 738            2              99              60                      17
# 739            1             102              74                       0
# 740           11             120              80                      37
# 741            3             102              44                      20
# 742            1             109              58                      18
# 743            9             140              94                       0
# 744           13             153              88                      37
# 745           12             100              84                      33
# 746            1             147              94                      41
# 747            1              81              74                      41
# 748            3             187              70                      22
# 749            6             162              62                       0
# 750            4             136              70                       0
# 751            1             121              78                      39
# 752            3             108              62                      24
# 753            0             181              88                      44
# 754            8             154              78                      32
# 755            1             128              88                      39
# 756            7             137              90                      41
# 757            0             123              72                       0
# 758            1             106              76                       0
# 759            6             190              92                       0
# 760            2              88              58                      26
# 761            9             170              74                      31
# 762            9              89              62                       0
# 763           10             101              76                      48
# 764            2             122              70                      27
# 765            5             121              72                      23
# 766            1             126              60                       0
# 767            1              93              70                      31
#
#      insulin   bmi  diabetes pedigree  age  diabetes  three
# 0          0  33.6              0.627   50      True   10.0
# 1          0  26.6              0.351   31     False    NaN
# 2          0  23.3              0.672   32      True   20.0
# 3         94  28.1              0.167   21     False   30.0
# 4        168  43.1              2.288   33      True    NaN
# 5          0  25.6              0.201   30     False    NaN
# 6         88  31.0              0.248   26      True    NaN
# 7          0  35.3              0.134   29     False    NaN
# 8        543  30.5              0.158   53      True    NaN
# 9          0   0.0              0.232   54      True    NaN
# 10         0  37.6              0.191   30     False    NaN
# 11         0  38.0              0.537   34      True    NaN
# 12         0  27.1              1.441   57     False    NaN
# 13       846  30.1              0.398   59      True    NaN
# 14       175  25.8              0.587   51      True    NaN
# 15         0  30.0              0.484   32      True    NaN
# 16       230  45.8              0.551   31      True    NaN
# 17         0  29.6              0.254   31      True    NaN
# 18        83  43.3              0.183   33     False    NaN
# 19        96  34.6              0.529   32      True    NaN
# 20       235  39.3              0.704   27     False    NaN
# 21         0  35.4              0.388   50     False    NaN
# 22         0  39.8              0.451   41      True    NaN
# 23         0  29.0              0.263   29      True    NaN
# 24       146  36.6              0.254   51      True    NaN
# 25       115  31.1              0.205   41      True    NaN
# 26         0  39.4              0.257   43      True    NaN
# 27       140  23.2              0.487   22     False    NaN
# 28       110  22.2              0.245   57     False    NaN
# 29         0  34.1              0.337   38     False    NaN
# ..       ...   ...                ...  ...       ...    ...
# 738      160  36.6              0.453   21     False    NaN
# 739        0  39.5              0.293   42      True    NaN
# 740      150  42.3              0.785   48      True    NaN
# 741       94  30.8              0.400   26     False    NaN
# 742      116  28.5              0.219   22     False    NaN
# 743        0  32.7              0.734   45      True    NaN
# 744      140  40.6              1.174   39     False    NaN
# 745      105  30.0              0.488   46     False    NaN
# 746        0  49.3              0.358   27      True    NaN
# 747       57  46.3              1.096   32     False    NaN
# 748      200  36.4              0.408   36      True    NaN
# 749        0  24.3              0.178   50      True    NaN
# 750        0  31.2              1.182   22      True    NaN
# 751       74  39.0              0.261   28     False    NaN
# 752        0  26.0              0.223   25     False    NaN
# 753      510  43.3              0.222   26      True    NaN
# 754        0  32.4              0.443   45      True    NaN
# 755      110  36.5              1.057   37      True    NaN
# 756        0  32.0              0.391   39     False    NaN
# 757        0  36.3              0.258   52      True    NaN
# 758        0  37.5              0.197   26     False    NaN
# 759        0  35.5              0.278   66      True    NaN
# 760       16  28.4              0.766   22     False    NaN
# 761        0  44.0              0.403   43      True    NaN
# 762        0  22.5              0.142   33     False    NaN
# 763      180  32.9              0.171   63     False    NaN
# 764        0  36.8              0.340   27     False    NaN
# 765      112  26.2              0.245   30     False    NaN
# 766        0  30.1              0.349   47      True    NaN
# 767        0  30.4              0.315   23     False    NaN
#
# [768 rows x 10 columns]

# %% [markdown]
# # Create Sample Data for Import

# %%
# Create Sample Data for Import
import pandas as pd

#The program below creates a sample data frame which can be used further for demonstration.
dt = {'ID': [11, 12, 13, 14, 15],
            'first_name': ['David', 'Jamie', 'Steve', 'Stevart', 'John'],
            'company': ['Aon', 'TCS', 'Google', 'RBS', '.'],
            'salary': [74, 76, 96, 71, 78]}
mydt = pd.DataFrame(dt, columns = ['ID', 'first_name', 'company', 'salary'])

mydt.head()

# now save this data as csv
# Out:
#    ID first_name company  salary
# 0  11      David     Aon      74
# 1  12      Jamie     TCS      76
# 2  13      Steve  Google      96
# 3  14    Stevart     RBS      71
# 4  15       John       .      78

# %% [markdown]
# # Save data as CSV in the working directory
# The following command tells python to write data in CSV format.

# %%
mydt.to_csv('newworkingfile.csv', index=True)
#true means save with index value
#false means don't

# %%
# Specify missing values
import pandas as pd
mydata00  = pd.read_csv("newworkingfile.csv", na_values=['.'])

# %%
# Set Index Column to ID
import pandas as pd
mydata01  = pd.read_csv("newworkingfile.csv", index_col ='ID')
mydata01
# Out:
#     Unnamed: 0 first_name company  salary
# ID
# 11           0      David     Aon      74
# 12           1      Jamie     TCS      76
# 13           2      Steve  Google      96
# 14           3    Stevart     RBS      71
# 15           4       John       .      78

# %% [markdown]
# # Set Index Column to ID

# %%
mydata05  = pd.read_csv("workingfile.csv", index_col ='ID')
mydata05
# Out:
#     Unnamed: 0 first_name company  salary
# ID
# 11           0      David     Aon      74
# 12           1      Jamie     TCS      76
# 13           2      Steve  Google      96
# 14           3    Stevart     RBS      71
# 15           4       John       .      78

# %% [markdown]
# # Read CSV File from URL
#
# You can directly read data from the CSV file that is stored on a web link.

# %%
import pandas as pd
mydata02  = pd.read_csv("http://winterolympicsmedals.com/medals.csv")
mydata02
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ~\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# ~\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# ~\Anaconda3\lib\http\client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# ~\Anaconda3\lib\http\client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     706     err = None
# --> 707     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     708         af, socktype, proto, canonname, sa = res
#
# ~\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-6-cf19b1be6dbd> in <module>
#       1 import pandas as pd
# ----> 2 mydata02  = pd.read_csv("http://winterolympicsmedals.com/medals.csv")
#       3 mydata02
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     411     compression = _infer_compression(filepath_or_buffer, compression)
#     412     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# --> 413         filepath_or_buffer, encoding, compression)
#     414     kwds['compression'] = compression
#     415
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     200
#     201     if _is_url(filepath_or_buffer):
# --> 202         req = _urlopen(filepath_or_buffer)
#     203         content_encoding = req.headers.get('Content-Encoding', None)
#     204         if content_encoding == 'gzip':
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_open(self, req)
#    1343
#    1344     def http_open(self, req):
# -> 1345         return self.do_open(http.client.HTTPConnection, req)
#    1346
#    1347     http_request = AbstractHTTPHandler.do_request_
#
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    
# 2290  2006     Turin     Skating   Figure skating  USA             individual
# 2291  2006     Turin     Skating   Short Track S.  USA                  1000m
# 2292  2006     Turin     Skating   Short Track S.  USA            5000m relay
# 2293  2006     Turin     Skating   Short Track S.  USA                   500m
# 2294  2006     Turin     Skating    Speed skating  USA                 10000m
# 2295  2006     Turin     Skating    Speed skating  USA                  1000m
# 2296  2006     Turin     Skating    Speed skating  USA                  1000m
# 2297  2006     Turin     Skating    Speed skating  USA                  1500m
# 2298  2006     Turin     Skating    Speed skating  USA                  1500m
# 2299  2006     Turin     Skating    Speed skating  USA                  5000m
# 2300  2006     Turin     Skating    Speed skating  USA                   500m
# 2301  2006     Turin      Skiing    Alpine Skiing  USA        Alpine combined
# 2302  2006     Turin      Skiing    Alpine Skiing  USA           giant slalom
# 2303  2006     Turin      Skiing   Freestyle Ski.  USA                 moguls
# 2304  2006     Turin      Skiing        Snowboard  USA  Giant parallel slalom
# 2305  2006     Turin      Skiing        Snowboard  USA              Half-pipe
# 2306  2006     Turin      Skiing        Snowboard  USA              Half-pipe
# 2307  2006     Turin      Skiing        Snowboard  USA              Half-pipe
# 2308  2006     Turin      Skiing        Snowboard  USA              Half-pipe
# 2309  2006     Turin      Skiing        Snowboard  USA        Snowboard Cross
# 2310  2006     Turin      Skiing        Snowboard  USA        Snowboard Cross
#
#      Event gender   Medal  Three
# 0               M  Silver   10.0
# 1               W    Gold    NaN
# 2               X    Gold   20.0
# 3               M  Bronze   30.0
# 4               M    Gold    NaN
# 5               M  Silver    NaN
# 6               X  Silver    NaN
# 7               M    Gold    NaN
# 8               M  Silver    NaN
# 9               M    Gold    NaN
# 10              M    Gold    NaN
# 11              M  Silver    NaN
# 12              M  Bronze    NaN
# 13              M  Bronze    NaN
# 14              M    Gold    NaN
# 15              M  Bronze    NaN
# 16              M  Bronze    NaN
# 17              M  Bronze    NaN
# 18              X  Bronze    NaN
# 19              M  Silver    NaN
# 20              M    Gold    NaN
# 21              M  Bronze    NaN
# 22              W  Bronze    NaN
# 23              M  Bronze    NaN
# 24              M  Bronze    NaN
# 25              M  Silver    NaN
# 26              M  Bronze    NaN
# 27              M  Bronze    NaN
# 28              M  Silver    NaN
# 29              M  Silver    NaN
# ...           ...     ...    ...
# 2281            M    Gold    NaN
# 2282            M    Gold    NaN
# 2283            W    Gold    NaN
# 2284            W  Bronze    NaN
# 2285            X  Bronze    NaN
# 2286            W  Silver    NaN
# 2287            M  Bronze    NaN
# 2288            W  Bronze    NaN
# 2289            X  Silver    NaN
# 2290            W  Silver    NaN
# 2291            M  Bronze    NaN
# 2292            M  Bronze    NaN
# 2293            M    Gold    NaN
# 2294            M  Silver    NaN
# 2295            M    Gold    NaN
# 2296            M  Silver    NaN
# 2297            M  Bronze    NaN
# 2298            M  Silver    NaN
# 2299            M    Gold    NaN
# 2300            M    Gold    NaN
# 2301            M    Gold    NaN
# 2302            W    Gold    NaN
# 2303            M  Bronze    NaN
# 2304            W  Bronze    NaN
# 2305            M    Gold    NaN
# 2306            M  Silver    NaN
# 2307            W    Gold    NaN
# 2308            W  Silver    NaN
# 2288  2006     Turin     Skating   Short Track S.  USA                   500m
# 2289  2006     Turin     Skating    Speed skating  USA                 10000m
# 2290  2006     Turin     Skating    Speed skating  USA                  1000m
# 2291  2006     Turin     Skating    Speed skating  USA                  1000m
# 2292  2006     Turin     Skating    Speed skating  USA                  1500m
# 2293  2006     Turin     Skating    Speed skating  USA                  1500m
# 2294  2006     Turin     Skating    Speed skating  USA                  5000m
# 2295  2006     Turin     Skating    Speed skating  USA                   500m
# 2296  2006     Turin      Skiing    Alpine Skiing  USA        Alpine combined
# 2297  2006     Turin      Skiing    Alpine Skiing  USA           giant slalom
# 2298  2006     Turin      Skiing   Freestyle Ski.  USA                 moguls
# 2299  2006     Turin      Skiing        Snowboard  USA  Giant parallel slalom
# 2300  2006     Turin      Skiing        Snowboard  USA              Half-pipe
# 2301  2006     Turin      Skiing        Snowboard  USA              Half-pipe
# 2302  2006     Turin      Skiing        Snowboard  USA              Half-pipe
# 2303  2006     Turin      Skiing        Snowboard  USA              Half-pipe
# 2304  2006     Turin      Skiing        Snowboard  USA        Snowboard Cross
# 2305  2006     Turin      Skiing        Snowboard  USA        Snowboard Cross
#
#       M    Gold
# 0     M  Silver
# 1     X  Silver
# 2     M    Gold
# 3     M  Silver
# 4     M    Gold
# 5     M    Gold
# 6     M  Silver
# 7     M  Bronze
# 8     M  Bronze
# 9     M    Gold
# 10    M  Bronze
# 11    M  Bronze
# 12    M  Bronze
# 13    X  Bronze
# 14    M  Silver
# 15    M    Gold
# 16    M  Bronze
# 17    W  Bronze
# 18    M  Bronze
# 19    M  Bronze
# 20    M  Silver
# 21    M  Bronze
# 22    M  Bronze
# 23    M  Silver
# 24    M  Silver
# 25    M    Gold
# 26    M  Silver
# 27    M  Bronze
# 28    M    Gold
# 29    M  Silver
# ...  ..     ...
# 2276  M    Gold
# 2277  M    Gold
# 2278  W    Gold
# 2279  W  Bronze
# 2280  X  Bronze
# 2281  W  Silver
# 2282  M  Bronze
# 2283  W  Bronze
# 2284  X  Silver
# 2285  W  Silver
# 2286  M  Bronze
# 2287  M  Bronze
# 2288  M    Gold
# 2289  M  Silver
# 2290  M    Gold
# 2291  M  Silver
# 2292  M  Bronze
# 2293  M  Silver
# 2294  M    Gold
# 2295  M    Gold
# 2296  M    Gold
# 2297  W    Gold
# 2298  M  Bronze
# 2299  W  Bronze
# 2300  M    Gold
# 2301  M  Silver
# 2302  W    Gold
# 2303  W  Silver
# 2304  M    Gold
# 2305  W  Silver
#
# [2306 rows x 8 columns]

# %% [markdown]
# # Skip Last 5 Rows While Importing CSV

# %%
import pandas as pd
mydata04  = pd.read_csv("http://winterolympicsmedals.com/medals.csv", skip_last=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-910625d4ab90> in <module>
#       1 import pandas as pd
# ----> 2 mydata04  = pd.read_csv("http://winterolympicsmedals.com/medals.csv", skip_last=5)
#
# TypeError: parser_f() got an unexpected keyword argument 'skip_last'

# %% [markdown]
# # Interpreting "," as thousands separator

# %%
import pandas as pd
mydata06 = pd.read_csv("http://winterolympicsmedals.com/medals.csv", thousands=",")
mydata06
# Out:
# 2297  2006     Turin     Skating    Speed skating  USA                  1500m
# 2298  2006     Turin     Skating    Speed skating  USA                  1500m
# 2299  2006     Turin     Skating    Speed skating  USA                  5000m
# 2300  2006     Turin     Skating    Speed skating  USA                   500m
# 2301  2006     Turin      Skiing    Alpine Skiing  USA        Alpine combined
# 2302  2006     Turin      Skiing    Alpine Skiing  USA           giant slalom
# 2303  2006     Turin      Skiing   Freestyle Ski.  USA                 moguls
# 2304  2006     Turin      Skiing        Snowboard  USA  Giant parallel slalom
# 2305  2006     Turin      Skiing        Snowboard  USA              Half-pipe
# 2306  2006     Turin      Skiing        Snowboard  USA              Half-pipe
# 2307  2006     Turin      Skiing        Snowboard  USA              Half-pipe
# 2308  2006     Turin      Skiing        Snowboard  USA              Half-pipe
# 2309  2006     Turin      Skiing        Snowboard  USA        Snowboard Cross
# 2310  2006     Turin      Skiing        Snowboard  USA        Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# 3               M  Bronze
# 4               M    Gold
# 5               M  Silver
# 6               X  Silver
# 7               M    Gold
# 8               M  Silver
# 9               M    Gold
# 10              M    Gold
# 11              M  Silver
# 12              M  Bronze
# 13              M  Bronze
# 14              M    Gold
# 15              M  Bronze
# 16              M  Bronze
# 17              M  Bronze
# 18              X  Bronze
# 19              M  Silver
# 20              M    Gold
# 21              M  Bronze
# 22              W  Bronze
# 23              M  Bronze
# 24              M  Bronze
# 25              M  Silver
# 26              M  Bronze
# 27              M  Bronze
# 28              M  Silver
# 29              M  Silver
# ...           ...     ...
# 2281            M    Gold
# 2282            M    Gold
# 2283            W    Gold
# 2284            W  Bronze
# 2285            X  Bronze
# 2286            W  Silver
# 2287            M  Bronze
# 2288            W  Bronze
# 2289            X  Silver
# 2290            W  Silver
# 2291            M  Bronze
# 2292            M  Bronze
# 2293            M    Gold
# 2294            M  Silver
# 2295            M    Gold
# 2296            M  Silver
# 2297            M  Bronze
# 2298            M  Silver
# 2299            M    Gold
# 2300            M    Gold
# 2301            M    Gold
# 2302            W    Gold
# 2303            M  Bronze
# 2304            W  Bronze
# 2305            M    Gold
# 2306            M  Silver
# 2307            W    Gold
# 2308            W  Silver
# 2309            M    Gold
# 2310            W  Silver
#
# [2311 rows x 8 columns]

# %% [markdown]
# # Read only specific columns

# %%
mydata07 = pd.read_csv("http://winterolympicsmedals.com/medals.csv", usecols=(1,5,7))
mydata07
# Out:
#           City                  Event   Medal
# 0     Chamonix             individual  Silver
# 1     Chamonix             individual    Gold
# 2     Chamonix                  pairs    Gold
# 3     Chamonix               four-man  Bronze
# 4     Chamonix             ice hockey    Gold
# 5     Chamonix        military patrol  Silver
# 6     Chamonix                  pairs  Silver
# 7     Chamonix                 10000m    Gold
# 8     Chamonix                 10000m  Silver
# 9     Chamonix                  1500m    Gold
# 10    Chamonix                  5000m    Gold
# 11    Chamonix                  5000m  Silver
# 12    Chamonix                   500m  Bronze
# 13    Chamonix    combined (4 events)  Bronze
# 14    Chamonix    combined (4 events)    Gold
# 15    Chamonix                   18km  Bronze
# 16    Chamonix        military patrol  Bronze
# 17    Chamonix                curling  Bronze
# 18    Chamonix                  pairs  Bronze
# 19    Chamonix               four-man  Silver
# 20    Chamonix                curling    Gold
# 21    Chamonix             ice hockey  Bronze
# 22    Chamonix             individual  Bronze
# 23    Chamonix                 10000m  Bronze
# 24    Chamonix                  1500m  Bronze
# 25    Chamonix                  1500m  Silver
# 26    Chamonix                  5000m  Bronze
# 27    Chamonix                   500m  Bronze
# 28    Chamonix                   500m  Silver
# 29    Chamonix    combined (4 events)  Silver
# ...        ...                    ...     ...
# 2281     Turin           Sprint 1.5km    Gold
# 2282     Turin            Team sprint    Gold
# 2283     Turin            Team sprint    Gold
# 2284     Turin                  7.5km  Bronze
# 2285     Turin            ice dancing  Bronze
# 2286     Turin                two-man  Silver
# 2287     Turin                curling  Bronze
# 2288     Turin             ice hockey  Bronze
# 2289     Turin            ice dancing  Silver
# 2290     Turin             individual  Silver
# 2291     Turin                  1000m  Bronze
# 2292     Turin            5000m relay  Bronze
# 2293     Turin                   500m    Gold
# 2294     Turin                 10000m  Silver
# 2295     Turin                  1000m    Gold
# 2296     Turin                  1000m  Silver
# 2297     Turin                  1500m  Bronze
# 2298     Turin                  1500m  Silver
# 2299     Turin                  5000m    Gold
# 2300     Turin                   500m    Gold
# 2301     Turin        Alpine combined    Gold
# 2302     Turin           giant slalom    Gold
# 2303     Turin                 moguls  Bronze
# 2304     Turin  Giant parallel slalom  Bronze
# 2305     Turin              Half-pipe    Gold
# 2306     Turin              Half-pipe  Silver
# 2307     Turin              Half-pipe    Gold
# 2308     Turin              Half-pipe  Silver
# 2309     Turin        Snowboard Cross    Gold
# 2310     Turin        Snowboard Cross  Silver
#
# [2311 rows x 3 columns]

# %% [markdown]
# # Read some rows and columns

# %%
import pandas as pd
mydata08 = pd.read_csv("http://winterolympicsmedals.com/medals.csv", usecols=(1,5,7),nrows=5)
mydata08['three']=pd.Series([10,20,30,90,18],index=[0,1,2,3,4])
mydata08
# Out:
#        City       Event   Medal  three
# 0  Chamonix  individual  Silver     10
# 1  Chamonix  individual    Gold     20
# 2  Chamonix       pairs    Gold     30
# 3  Chamonix    four-man  Bronze     90
# 4  Chamonix  ice hockey    Gold     18

# %% [markdown]
# # Read Text File
#
# We can use read_table() function to pull data from text file. We can also use read_csv() with sep= "\t" to read data from tab-separated file.

# %%
mydata = pd.read_table("C:\\Users\\Deepanshu\\Desktop\\example2.txt")
mydata  = pd.read_csv("C:\\Users\\Deepanshu\\Desktop\\example2.txt", sep ="\t")

# %% [markdown]
# # Read Excel File
#
# The read_excel() function can be used to import excel data into Python.

# %%
mydata = pd.read_excel("https://www.eia.gov/dnav/pet/hist_xls/RBRTEd.xls",sheetname="Data 1", skiprows=2)

#If you do not specify name of sheet in sheetname= option, it would take by default first sheet.

mydata
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
#            Date  Europe Brent Spot Price FOB (Dollars per Barrel)
# 0    1987-05-20                                             18.63
# 1    1987-05-21                                             18.45
# 2    1987-05-22                                             18.55
# 3    1987-05-25                                             18.60
# 4    1987-05-26                                             18.63
# 5    1987-05-27                                             18.60
# 6    1987-05-28                                             18.60
# 7    1987-05-29                                             18.58
# 8    1987-06-01                                             18.65
# 9    1987-06-02                                             18.68
# 10   1987-06-03                                             18.75
# 11   1987-06-04                                             18.78
# 12   1987-06-05                                             18.65
# 13   1987-06-08                                             18.75
# 14   1987-06-09                                             18.78
# 15   1987-06-10                                             18.78
# 16   1987-06-11                                             18.68
# 17   1987-06-12                                             18.78
# 18   1987-06-16                                             18.90
# 19   1987-06-17                                             19.03
# 20   1987-06-18                                             19.05
# 21   1987-06-19                                             19.05
# 22   1987-06-22                                             19.10
# 23   1987-06-23                                             18.90
# 24   1987-06-24                                             18.75
# 25   1987-06-25                                             18.70
# 26   1987-06-26                                             19.08
# 27   1987-06-29                                             19.15
# 28   1987-06-30                                             19.08
# 29   1987-07-01                                             18.98
# ...         ...                                               ...
# 8111 2019-05-06                                             71.95
# 8112 2019-05-07                                             70.98
# 8113 2019-05-08                                             71.09
# 8114 2019-05-09                                             70.61
# 8115 2019-05-10                                             71.63
# 8116 2019-05-13                                             72.35
# 8117 2019-05-14                                             72.53
# 8118 2019-05-15                                             73.09
# 8119 2019-05-16                                             74.70
# 8120 2019-05-17                                             73.94
# 8121 2019-05-20                                             73.21
# 8122 2019-05-21                                             72.94
# 8123 2019-05-22                                             71.94
# 8124 2019-05-23                                             68.37
# 8125 2019-05-24                                             67.98
# 8126 2019-05-28                                             70.19
# 8127 2019-05-29                                             70.64
# 8128 2019-05-30                                             69.55
# 8129 2019-05-31                                             66.78
# 8130 2019-06-03                                             63.16
# 8131 2019-06-04                                             63.56
# 8132 2019-06-05                                             62.14
# 8133 2019-06-06                                             62.77
# 8134 2019-06-07                                             64.10
# 8135 2019-06-10                                             64.31
# 8136 2019-06-11                                             63.56
# 8137 2019-06-12                                             61.66
# 8138 2019-06-13                                             63.28
# 8139 2019-06-14                                             63.13
# 8140 2019-06-17                                             62.56
#
# [8141 rows x 2 columns]

# %%
# To include variable names, use the names= option like below 

mydata3 = pd.read_table("http://www.ssc.wisc.edu/~bhansen/econometrics/invest.dat", sep="\s+", names=['a', 'b', 'c', 'd'])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-62-1f52ba7b07d2> in <module>()
#       1 # To include variable names, use the names= option like below
#       2
# ----> 3 mydata3 = pd.read_table("http://www.ssc.wisc.edu/~bhansen/econometrics/invest.dat", sep="\s+", names=['a', 'b', 'c', 'd'])
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     422     compression = _infer_compression(filepath_or_buffer, compression)
#     423     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# --> 424         filepath_or_buffer, encoding, compression)
#     425     kwds['compression'] = compression
#     426
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     193
#     194     if _is_url(filepath_or_buffer):
# --> 195         req = _urlopen(filepath_or_buffer)
#     196         content_encoding = req.headers.get('Content-Encoding', None)
#     197         if content_encoding == 'gzip':
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     562             http_err = 0
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#     566             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     754         fp.close()
#     755
# --> 756         return self.parent.open(new, timeout=req.timeout)
#     757
#     758     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %%
pwd
# Out:
# 'C:\\Users\\croma\\Dexlab python'
